# %%
import pandas as pd

# %%
df = pd.read_csv('data/unpacked/data.csv')

# %%
df
# Out:
#           Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0                  0   2539329        1    prior             1          2
# 1                  1   2398795        1    prior             2          3
# 2                  2    473747        1    prior             3          3
# 3                  3   2254736        1    prior             4          4
# 4                  4    431534        1    prior             5          4
# 5                  5   3367565        1    prior             6          2
# 6                  6    550135        1    prior             7          1
# 7                  7   3108588        1    prior             8          1
# 8                  8   2295261        1    prior             9          1
# 9                  9   2550362        1    prior            10          4
# 10                10   2968173       15    prior            15          1
# 11                11   1870022       15    prior            17          2
# ...

# %%
df_count = df.groupby(by='product_id').count()

# %%
df_count
# Out:
#             Unnamed: 0  order_id  user_id  eval_set  order_number  order_dow  \
# product_id
# 1                 1928      1928     1928      1928          1928       1928
# 2                   94        94       94        94            94         94
# 3                  283       283      283       283           283        283
# 4                  351       351      351       351           351        351
# 5                   16        16       16        16            16         16
# 6                    8         8        8         8             8          8
# 7                   31        31       31        31            31         31
# 8                  178       178      178       178           178        178
# 9                  161       161      161       161           161        161
# 10                2691      2691     2691      2691          2691       2691
# 11                 106       106      106       106           106        106
# ...

# %%
df_count.sort_values(by='order_id', ascending=False)
# Out:
#             Unnamed: 0  order_id  user_id  eval_set  order_number  order_dow  \
# product_id
# 24852           491291    491291   491291    491291        491291     491291
# 13176           394930    394930   394930    394930        394930     394930
# 21137           275577    275577   275577    275577        275577     275577
# 21903           251705    251705   251705    251705        251705     251705
# 47209           220877    220877   220877    220877        220877     220877
# 47766           184224    184224   184224    184224        184224     184224
# 47626           160792    160792   160792    160792        160792     160792
# 16797           149445    149445   149445    149445        149445     149445
# 26209           146660    146660   146660    146660        146660     146660
# 27845           142813    142813   142813    142813        142813     142813
# 27966           142603    142603   142603    142603        142603     142603
# ...
